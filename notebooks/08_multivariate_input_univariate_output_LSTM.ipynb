# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Loading the dataset
df = pd.read_csv("../data/processed/merged_multivariate_dataset_cleaned.csv")
df['Date'] = pd.to_datetime(df['Date'])

# List of baraj fill ratio columns (target columns to forecast)
baraj_targets = [col for col in df.columns if col.endswith('_Fill')]

# Creating lag and rolling mean features for each target
for target in baraj_targets:
    df[f"{target}_lag1"] = df[target].shift(1)
    df[f"{target}_rolling7"] = df[target].rolling(window=7).mean()

# Dropping rows with NaNs after feature engineering
df = df.dropna().reset_index(drop=True)

# Saving original dates for later slicing
dates = df['Date'].reset_index(drop=True)

# Looping through each baraj to train a model and plot results
for target_column in baraj_targets:
    print(f"\nTraining model for: {target_column}")

    # Selecting features (excluding Date and current target)
    feature_columns = df.columns.difference(['Date'] + baraj_targets).tolist()
    X = df[feature_columns]
    y = df[[target_column]]

    # Scaling the features
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)
    y_scaled = scaler_y.fit_transform(y)

    # Creating sequences for LSTM input
    def create_sequences(X, y, time_steps=60):
        Xs, ys = [], []
        for i in range(len(X) - time_steps):
            Xs.append(X[i:(i + time_steps)])
            ys.append(y[i + time_steps])
        return np.array(Xs), np.array(ys)

    time_steps = 60
    X_seq, y_seq = create_sequences(X_scaled, y_scaled)
    date_seq = dates[time_steps:]  # Aligning dates with y_seq

    # Splitting the data
    train_size = int(len(X_seq) * 0.7)
    val_size = int(len(X_seq) * 0.1)
    X_train, y_train = X_seq[:train_size], y_seq[:train_size]
    X_val, y_val = X_seq[train_size:train_size + val_size], y_seq[train_size:train_size + val_size]
    X_test, y_test = X_seq[train_size + val_size:], y_seq[train_size + val_size:]
    date_test = date_seq[train_size + val_size:]

    # Building the LSTM model with Dropout
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, activation='tanh', input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(32, activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse')

    # Training the model and storing the history
    history = model.fit(X_train, y_train, epochs=30, batch_size=32,
                        validation_data=(X_val, y_val), verbose=1)

    # Making predictions
    y_pred = model.predict(X_test)
    y_pred_inv = scaler_y.inverse_transform(y_pred)
    y_test_inv = scaler_y.inverse_transform(y_test)

    # Calculating metrics
    mae = mean_absolute_error(y_test_inv, y_pred_inv)
    rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
    print(f"MAE: {round(mae, 4)} | RMSE: {round(rmse, 4)}")

    # Plotting predictions
    plt.figure(figsize=(14, 5))
    plt.plot(date_test, y_test_inv, label=f"Actual {target_column}")
    plt.plot(date_test, y_pred_inv, label=f"Predicted {target_column}")
    plt.title(f"LSTM Forecast for {target_column}")
    plt.xlabel("Date")
    plt.ylabel("Fill Ratio")
    plt.legend()
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    # Plotting training and validation loss
    plt.figure(figsize=(10, 4))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f"Loss Curve for {target_column}")
    plt.xlabel("Epochs")
    plt.ylabel("Loss (MSE)")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# Training model for: Omerli_Fill
# Epoch 1/30
# C:\Users\merta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.1032 - val_loss: 0.0105
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0087 - val_loss: 0.0040
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0068 - val_loss: 0.0042
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0057 - val_loss: 0.0041
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0056 - val_loss: 0.0047
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0051 - val_loss: 0.0046
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0047 - val_loss: 0.0061
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0046 - val_loss: 0.0063
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0047 - val_loss: 0.0040
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0039 - val_loss: 0.0051
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0043 - val_loss: 0.0050
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0041 - val_loss: 0.0049
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0041 - val_loss: 0.0049
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0030 - val_loss: 0.0049
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0031 - val_loss: 0.0055
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0033 - val_loss: 0.0046
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0030 - val_loss: 0.0050
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0026 - val_loss: 0.0047
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0026 - val_loss: 0.0049
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0024 - val_loss: 0.0047
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0024 - val_loss: 0.0046
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0023 - val_loss: 0.0043
# Epoch 26/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0023 - val_loss: 0.0050
# Epoch 27/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0020 - val_loss: 0.0050
# Epoch 28/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0019 - val_loss: 0.0050
# Epoch 29/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0018 - val_loss: 0.0056
# Epoch 30/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0018 - val_loss: 0.0051
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# MAE: 0.0411 | RMSE: 0.0501
# Training model for: Terkos_Fill
# Epoch 1/30
# C:\Users\merta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.0588 - val_loss: 0.0098
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0106 - val_loss: 0.0055
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0075 - val_loss: 0.0019
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0066 - val_loss: 0.0031
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0063 - val_loss: 0.0025
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0070 - val_loss: 0.0018
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0053 - val_loss: 8.1606e-04
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0050 - val_loss: 0.0020
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0048 - val_loss: 9.9873e-04
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0045 - val_loss: 7.8668e-04
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0041 - val_loss: 0.0018
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0043 - val_loss: 8.9257e-04
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0035 - val_loss: 7.0201e-04
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0038 - val_loss: 8.0897e-04
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0039 - val_loss: 9.4808e-04
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0032 - val_loss: 0.0010
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0031 - val_loss: 8.2427e-04
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0030 - val_loss: 9.0499e-04
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0029 - val_loss: 8.2595e-04
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0027 - val_loss: 6.5378e-04
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0025 - val_loss: 0.0010
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0027 - val_loss: 5.1491e-04
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0022 - val_loss: 8.0856e-04
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 26/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0020 - val_loss: 9.6396e-04
# Epoch 27/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0020 - val_loss: 0.0010
# Epoch 28/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 29/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 30/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0017 - val_loss: 9.0227e-04
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# MAE: 0.0271 | RMSE: 0.0312
# Training model for: Alibey_Fill
# Epoch 1/30
# C:\Users\merta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0601 - val_loss: 0.0036
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0079 - val_loss: 0.0040
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0071 - val_loss: 0.0026
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0059 - val_loss: 0.0017
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0055 - val_loss: 0.0020
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0047 - val_loss: 0.0015
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0047 - val_loss: 0.0019
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0039 - val_loss: 0.0029
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0044 - val_loss: 0.0019
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0033 - val_loss: 9.4263e-04
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0034 - val_loss: 7.0631e-04
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0033 - val_loss: 0.0011
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0031 - val_loss: 6.8479e-04
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0027 - val_loss: 6.4879e-04
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0030 - val_loss: 6.4418e-04
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0025 - val_loss: 7.8316e-04
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0025 - val_loss: 7.8153e-04
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0023 - val_loss: 6.2472e-04
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0021 - val_loss: 4.5433e-04
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0020 - val_loss: 4.6391e-04
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0022 - val_loss: 5.7684e-04
# Epoch 26/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0020 - val_loss: 7.6508e-04
# Epoch 27/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 28/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0020 - val_loss: 5.1303e-04
# Epoch 29/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0017 - val_loss: 5.6117e-04
# Epoch 30/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0017 - val_loss: 8.8058e-04
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# MAE: 0.0342 | RMSE: 0.0399
# Training model for: Kazandere_Fill
# Epoch 1/30
# C:\Users\merta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.1149 - val_loss: 0.0031
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - loss: 0.0110 - val_loss: 0.0042
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0099 - val_loss: 0.0033
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0083 - val_loss: 0.0024
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0081 - val_loss: 0.0024
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0074 - val_loss: 0.0026
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 7s 42ms/step - loss: 0.0068 - val_loss: 0.0051
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - loss: 0.0066 - val_loss: 0.0032
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 0.0067 - val_loss: 0.0027
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.0064 - val_loss: 0.0022
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0064 - val_loss: 0.0035
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0058 - val_loss: 0.0024
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0057 - val_loss: 0.0023
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0058 - val_loss: 0.0023
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0048 - val_loss: 0.0035
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0054 - val_loss: 0.0026
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0051 - val_loss: 0.0028
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0045 - val_loss: 0.0020
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0048 - val_loss: 0.0024
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0044 - val_loss: 0.0020
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0043 - val_loss: 0.0021
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0041 - val_loss: 0.0024
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0037 - val_loss: 0.0023
# Epoch 26/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0036 - val_loss: 0.0030
# Epoch 27/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 28/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0036 - val_loss: 0.0025
# Epoch 29/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0035 - val_loss: 0.0022
# Epoch 30/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0031 - val_loss: 0.0019
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# MAE: 0.0683 | RMSE: 0.0791
# Training model for: Pabucdere_Fill
# Epoch 1/30
# C:\Users\merta\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - loss: 0.0391 - val_loss: 0.0040
# Epoch 2/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0087 - val_loss: 0.0045
# Epoch 3/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0075 - val_loss: 0.0063
# Epoch 4/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0068 - val_loss: 0.0046
# Epoch 5/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0059 - val_loss: 0.0016
# Epoch 6/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0062 - val_loss: 0.0020
# Epoch 7/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0059 - val_loss: 0.0024
# Epoch 8/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 0.0051 - val_loss: 0.0011
# Epoch 9/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - loss: 0.0050 - val_loss: 0.0015
# Epoch 10/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - loss: 0.0048 - val_loss: 5.7959e-04
# Epoch 11/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0044 - val_loss: 0.0012
# Epoch 12/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0041 - val_loss: 0.0010
# Epoch 13/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0043 - val_loss: 7.4381e-04
# Epoch 14/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0041 - val_loss: 0.0014
# Epoch 15/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0037 - val_loss: 4.8304e-04
# Epoch 16/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0037 - val_loss: 8.6071e-04
# Epoch 17/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0039 - val_loss: 6.8057e-04
# Epoch 18/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0033 - val_loss: 0.0024
# Epoch 19/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 20/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 21/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0029 - val_loss: 0.0015
# Epoch 22/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0030 - val_loss: 0.0013
# Epoch 23/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0026 - val_loss: 6.7032e-04
# Epoch 24/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0028 - val_loss: 0.0015
# Epoch 25/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 0.0028 - val_loss: 0.0012
# Epoch 26/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0025 - val_loss: 8.7694e-04
# Epoch 27/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 0.0024 - val_loss: 0.0014
# Epoch 28/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0023 - val_loss: 8.1268e-04
# Epoch 29/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 30/30
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0023 - val_loss: 0.0013
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# MAE: 0.03 | RMSE: 0.0452

# %%
# Getting the list of all dates after dropping NA
dates = df['Date'].reset_index(drop=True)

# Calculating how many dates were lost due to sequence length and dropped rows
time_steps = 60
total_sequences = len(dates) - time_steps

# Getting test start index (after splitting: 70% train, 10% val)
test_start_index = int(total_sequences * 0.8) + time_steps  # +time_steps accounts for initial sequence loss

# Extracting corresponding dates for the test set
test_dates = dates[test_start_index:test_start_index + len(y_test_inv)]

# Plotting the prediction vs actual with dates on x-axis
plt.figure(figsize=(14, 6))
plt.plot(test_dates, y_test_inv, label="Actual Ömerli Fill Ratio")
plt.plot(test_dates, y_pred_inv, label="Predicted Ömerli Fill Ratio")
plt.title("LSTM Forecast for Ömerli Fill Ratio")
plt.xlabel("Date")
plt.ylabel("Fill Ratio")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
